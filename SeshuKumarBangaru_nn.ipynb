# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import glob
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("gdrive/MyDrive/ISIC/Train")
data_dir_test = pathlib.Path('gdrive/MyDrive/ISIC/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    "gdrive/MyDrive/ISIC/Train",
    batch_size=batch_size,
    image_size=(img_height, img_width),
    seed=123,
    validation_split=0.2,
    subset="training"
)##todo
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
    "gdrive/MyDrive/ISIC/Train",
    batch_size=batch_size,
    image_size=(img_height, img_width),
    seed=123,
    validation_split=0.2,
    subset="validation"
)##todo
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  each_class_name=class_names[i]
  first_ins_of_each_class=list(data_dir_train.glob(each_class_name+'/*.jpg'))[1]
  img = plt.imread(str(first_ins_of_each_class))
  plt.title(each_class_name)
  plt.imshow(img)
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu', input_shape = (img_height, img_width, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 224s 841ms/step - loss: 2.0694 - accuracy: 0.1741 - val_loss: 2.0384 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 4s 75ms/step - loss: 2.0282 - accuracy: 0.1925 - val_loss: 2.0157 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9311 - accuracy: 0.2584 - val_loss: 2.0185 - val_accuracy: 0.1924
# Epoch 4/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.8884 - accuracy: 0.2612 - val_loss: 1.7945 - val_accuracy: 0.3266
# Epoch 5/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.8057 - accuracy: 0.3220 - val_loss: 1.7482 - val_accuracy: 0.3468
# Epoch 6/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.7105 - accuracy: 0.3510 - val_loss: 1.6979 - val_accuracy: 0.3781
# Epoch 7/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5866 - accuracy: 0.4035 - val_loss: 1.5817 - val_accuracy: 0.4362
# Epoch 8/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5352 - accuracy: 0.4353 - val_loss: 1.6381 - val_accuracy: 0.4430
# Epoch 9/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.4521 - accuracy: 0.4671 - val_loss: 1.6635 - val_accuracy: 0.4094
# Epoch 10/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.3619 - accuracy: 0.5028 - val_loss: 1.6516 - val_accuracy: 0.4318
# Epoch 11/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.2440 - accuracy: 0.5424 - val_loss: 1.6772 - val_accuracy: 0.4519
# Epoch 12/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.1544 - accuracy: 0.5882 - val_loss: 1.7088 - val_accuracy: 0.4027
# Epoch 13/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0778 - accuracy: 0.6189 - val_loss: 1.9098 - val_accuracy: 0.4295
# Epoch 14/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.9346 - accuracy: 0.6652 - val_loss: 2.1048 - val_accuracy: 0.4072
# Epoch 15/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.8492 - accuracy: 0.6836 - val_loss: 2.3035 - val_accuracy: 0.4407
# Epoch 16/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.9111 - accuracy: 0.6657 - val_loss: 2.2356 - val_accuracy: 0.3803
# Epoch 17/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.7447 - accuracy: 0.7338 - val_loss: 2.4836 - val_accuracy: 0.4497
# Epoch 18/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.6206 - accuracy: 0.7818 - val_loss: 2.8030 - val_accuracy: 0.3848
# Epoch 19/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.6440 - accuracy: 0.7656 - val_loss: 2.7485 - val_accuracy: 0.4027
# Epoch 20/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.6315 - accuracy: 0.7762 - val_loss: 2.5737 - val_accuracy: 0.4430

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# #### This shows that this model is Overfitting as Training Accuracy is 0.77 and Validation Accuracy is 0.44

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augument = keras.Sequential([
                                  layers.experimental.preprocessing.RandomRotation(0.2),
                                  layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                                  layers.experimental.preprocessing.RandomZoom(.5, .2)])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu', input_shape = (img_height, img_width, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history =model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
) ## your training code
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 7s 92ms/step - loss: 2.0134 - accuracy: 0.2271 - val_loss: 1.8802 - val_accuracy: 0.2975
# Epoch 2/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.8471 - accuracy: 0.3175 - val_loss: 1.8177 - val_accuracy: 0.3535
# Epoch 3/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7178 - accuracy: 0.3767 - val_loss: 1.7346 - val_accuracy: 0.3915
# Epoch 4/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7012 - accuracy: 0.3979 - val_loss: 1.6514 - val_accuracy: 0.4430
# Epoch 5/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5843 - accuracy: 0.4291 - val_loss: 1.5524 - val_accuracy: 0.4743
# Epoch 6/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5904 - accuracy: 0.4275 - val_loss: 1.6146 - val_accuracy: 0.4183
# Epoch 7/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5370 - accuracy: 0.4559 - val_loss: 1.5047 - val_accuracy: 0.4586
# Epoch 8/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5293 - accuracy: 0.4559 - val_loss: 1.4834 - val_accuracy: 0.4877
# Epoch 9/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5061 - accuracy: 0.4559 - val_loss: 1.5779 - val_accuracy: 0.4676
# Epoch 10/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4876 - accuracy: 0.4632 - val_loss: 1.4702 - val_accuracy: 0.4989
# Epoch 11/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4631 - accuracy: 0.4877 - val_loss: 1.5523 - val_accuracy: 0.4295
# Epoch 12/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4859 - accuracy: 0.4866 - val_loss: 1.5625 - val_accuracy: 0.4407
# Epoch 13/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4710 - accuracy: 0.4682 - val_loss: 1.4393 - val_accuracy: 0.4899
# Epoch 14/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4159 - accuracy: 0.5033 - val_loss: 1.4662 - val_accuracy: 0.4743
# Epoch 15/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.3953 - accuracy: 0.5033 - val_loss: 1.4022 - val_accuracy: 0.4966
# Epoch 16/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4052 - accuracy: 0.5011 - val_loss: 1.4495 - val_accuracy: 0.5034
# Epoch 17/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.3903 - accuracy: 0.5089 - val_loss: 1.4103 - val_accuracy: 0.5101
# Epoch 18/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.3813 - accuracy: 0.5089 - val_loss: 1.4528 - val_accuracy: 0.4609
# Epoch 19/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4143 - accuracy: 0.4933 - val_loss: 1.3986 - val_accuracy: 0.5101
# Epoch 20/20
# 56/56 [==============================] - 5s 87ms/step - loss: 1.3557 - accuracy: 0.5117 - val_loss: 1.4051 - val_accuracy: 0.4877

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# #### Both the Training and Validation Accuracies are 0.51 and 0.48, which shows now the model is Underfitting.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
count_of_imgs=[]
for name in class_names:
    list_of_imgs=list(data_dir_train.glob(name+'/*.jpg'))
    count_of_imgs.append(len(list_of_imgs))
plt.figure(figsize=(25,10))
plt.bar(class_names,count_of_imgs)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #####- seborrheic keratosis has less no. of samples
# #### - Which classes dominate the data in terms proportionate number of samples?
# #####- melanoma and pigmented benign keratosis dominate the data in terms proportionate number of samples

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
##
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
# Create original_df
path_list = [x for x in glob.glob(os.path.join(data_dir_train, '*/*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob.glob(os.path.join(data_dir_train, '*/*.jpg'))]
dataframe_dict = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict.items()),columns = ['Path','Label'])

# %%
original_df
# Out:
#                                                    Path              Label
# 0     gdrive/MyDrive/ISIC/Train/actinic keratosis/IS...  actinic keratosis
# 1     gdrive/MyDrive/ISIC/Train/actinic keratosis/IS...  actinic keratosis
# 2     gdrive/MyDrive/ISIC/Train/actinic keratosis/IS...  actinic keratosis
# 3     gdrive/MyDrive/ISIC/Train/actinic keratosis/IS...  actinic keratosis
# 4     gdrive/MyDrive/ISIC/Train/actinic keratosis/IS...  actinic keratosis
# ...                                                 ...                ...
# 2234  gdrive/MyDrive/ISIC/Train/dermatofibroma/ISIC_...     dermatofibroma
# 2235  gdrive/MyDrive/ISIC/Train/dermatofibroma/ISIC_...     dermatofibroma
# 2236  gdrive/MyDrive/ISIC/Train/dermatofibroma/ISIC_...     dermatofibroma
# 2237  gdrive/MyDrive/ISIC/Train/dermatofibroma/ISIC_...     dermatofibroma
# 2238  gdrive/MyDrive/ISIC/Train/dermatofibroma/ISIC_...     dermatofibroma
#
# [2239 rows x 2 columns]

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="gdrive/MyDrive/ISIC/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F02720AB810>: 100%|██████████| 500/500 [00:21<00:00, 22.85 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F02723CA310>: 100%|██████████| 500/500 [00:20<00:00, 24.54 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F02F01582D0>: 100%|██████████| 500/500 [00:22<00:00, 22.61 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F0272069750>: 100%|██████████| 500/500 [01:49<00:00,  4.57 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=919x802 at 0x7F02723CA510>: 100%|██████████| 500/500 [01:21<00:00,  6.12 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F0272118050>: 100%|██████████| 500/500 [00:18<00:00, 27.01 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F02723CFA50>: 100%|██████████| 500/500 [00:41<00:00, 12.17 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F0305431450>: 100%|██████████| 500/500 [00:18<00:00, 27.27 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/MyDrive/ISIC/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F03053C65D0>: 100%|██████████| 500/500 [00:18<00:00, 26.41 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# Create original_df
path_list_new = [x for x in glob.glob(os.path.join(data_dir_train,  '*','output', '*.jpg'))]
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train,  '*','output', '*.jpg'))]
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])

#path_list_new = [x for x in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
#path_list_new

# %%
#lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
#lesion_list_new
df2

# %%
#dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
#df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="gdrive/MyDrive/ISIC/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation", ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs =50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
#
50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2237 - accuracy: 0.9293 - val_loss: 1.2699 - val_accuracy: 0.7520
# Epoch 26/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2149 - accuracy: 0.9332 - val_loss: 1.1546 - val_accuracy: 0.7558
# Epoch 27/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2087 - accuracy: 0.9319 - val_loss: 1.1518 - val_accuracy: 0.7602
# Epoch 28/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2153 - accuracy: 0.9286 - val_loss: 1.2141 - val_accuracy: 0.7706
# Epoch 29/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2089 - accuracy: 0.9330 - val_loss: 1.1965 - val_accuracy: 0.7602
# Epoch 30/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.2310 - accuracy: 0.9280 - val_loss: 1.0625 - val_accuracy: 0.7788
# Epoch 31/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1928 - accuracy: 0.9394 - val_loss: 1.2834 - val_accuracy: 0.7476
# Epoch 32/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1653 - accuracy: 0.9466 - val_loss: 1.1764 - val_accuracy: 0.7765
# Epoch 33/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1683 - accuracy: 0.9486 - val_loss: 1.4199 - val_accuracy: 0.7528
# Epoch 34/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.2085 - accuracy: 0.9334 - val_loss: 1.1994 - val_accuracy: 0.7795
# Epoch 35/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1506 - accuracy: 0.9507 - val_loss: 1.2076 - val_accuracy: 0.7803
# Epoch 36/50
# 169/169 [==============================] - 32s 182ms/step - loss: 0.1651 - accuracy: 0.9514 - val_loss: 1.1722 - val_accuracy: 0.7728
# Epoch 37/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1962 - accuracy: 0.9377 - val_loss: 1.1318 - val_accuracy: 0.7639
# Epoch 38/50
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2046 - accuracy: 0.9312 - val_loss: 1.2613 - val_accuracy: 0.7654
# Epoch 39/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1788 - accuracy: 0.9423 - val_loss: 1.3353 - val_accuracy: 0.7550
# Epoch 40/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1793 - accuracy: 0.9394 - val_loss: 1.2989 - val_accuracy: 0.7684
# Epoch 41/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1634 - accuracy: 0.9486 - val_loss: 1.2632 - val_accuracy: 0.7654
# Epoch 42/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1692 - accuracy: 0.9483 - val_loss: 1.6715 - val_accuracy: 0.7513
# Epoch 43/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1510 - accuracy: 0.9514 - val_loss: 1.5170 - val_accuracy: 0.7491
# Epoch 44/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1664 - accuracy: 0.9507 - val_loss: 1.2325 - val_accuracy: 0.7780
# Epoch 45/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1630 - accuracy: 0.9509 - val_loss: 1.2914 - val_accuracy: 0.7825
# Epoch 46/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1407 - accuracy: 0.9547 - val_loss: 1.3546 - val_accuracy: 0.7699
# Epoch 47/50
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1577 - accuracy: 0.9522 - val_loss: 1.4881 - val_accuracy: 0.7394
# Epoch 48/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1314 - accuracy: 0.9570 - val_loss: 1.3971 - val_accuracy: 0.7565
# Epoch 49/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1403 - accuracy: 0.9573 - val_loss: 1.3882 - val_accuracy: 0.7543
# Epoch 50/50
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1334 - accuracy: 0.9583 - val_loss: 1.3353 - val_accuracy: 0.7721

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ###Class Rebalance definitely helped in improving the model performance. But I still see that there is a larger gap between Training Accuracy (0.95) and Validation Accuracy (0.77). Which means that we can still improve the model.
